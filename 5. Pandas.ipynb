# %%
import pandas as pd

# %%
california = pd.read_csv('/content/california.csv')

# %%
california
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0

# %% [markdown]
# <br>

# %% [markdown]
# **Accessing Data from Dataframe**

# %%
# Single columns

california['latitude']
# Out:
# 0    37.37
# 1    34.26
# 2    33.78
# 3    33.82
# 4    36.33
# Name: latitude, dtype: float64

# %%
# Multiple Columns

california[['latitude', 'total_rooms']]
# Out:
#    latitude  total_rooms
# 0     37.37       3885.0
# 1     34.26       1510.0
# 2     33.78       3589.0
# 3     33.82         67.0
# 4     36.33       1241.0

# %%
# Taking data types

california.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# **Storing Data**

# %%
data = '''id,name,category,description,comments
1,Apple,Fruit,Red and sweet,Good for snacks
2,Banana,Fruit,Yellow and soft,Rich in potassium
3,Carrot,Vegetable,Orange and crunchy,Great for salads
4,Desk,Furniture,Wooden study desk,Needs assembly
5,Chair,Furniture,Comfortable office chair,Ergonomic'''

# %%
from io import StringIO
df = pd.read_csv(StringIO(data))

df.to_csv('new_csv.csv', index=True)

# %%
from io import StringIO
df = pd.read_csv(StringIO(data))

df.to_excel("new_excel.xlsx", index=True)
# Out:
#    id    name   category               description           comments
# 0   1   Apple      Fruit             Red and sweet    Good for snacks
# 1   2  Banana      Fruit           Yellow and soft  Rich in potassium
# 2   3  Carrot  Vegetable        Orange and crunchy   Great for salads
# 3   4    Desk  Furniture         Wooden study desk     Needs assembly
# 4   5   Chair  Furniture  Comfortable office chair          Ergonomic

# %% [markdown]
# <br>

# %% [markdown]
# **Data Type Filtering**

# %%
df.dtypes[df.dtypes=='float64'].describe()
# Out:
# count           5
# unique          1
# top       float64
# freq            5
# dtype: object

# %% [markdown]
# **Slicing**

# %%
new_df = df[1:3]
new_df
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0

# %%
import numpy as np

new_df['longitude'] = np.random.randint(100, 430)
new_df
# Out:
# /tmp/ipython-input-3606858355.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['longitude'] = np.random.randint(100, 430)
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 1        308     34.26                43.0       1510.0           310.0
# 2        308     33.78                27.0       3589.0           507.0

# %%
new_df['lati_longi'] = df['latitude'].astype(str) + " " + df['longitude'].astype(str)
new_df
# Out:
# /tmp/ipython-input-3038944199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['lati_longi'] = df['latitude'].astype(str) + " " + df['longitude'].astype(str)
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        308     34.26                43.0       1510.0           310.0
# 2        308     33.78                27.0       3589.0           507.0
#
#       lati_longi
# 1   34.26 -118.3
# 2  33.78 -117.81

# %%
print(new_df)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        308     34.26                43.0       1510.0           310.0
# 2        308     33.78                27.0       3589.0           507.0
#
#                                           lati_longi
# 1  0    37.37\n1    34.26\n2    33.78\n3    33.82...
# 2  0    37.37\n1    34.26\n2    33.78\n3    33.82...

# %%
import seaborn as sns

# List all available datasets
datasets = sns.get_dataset_names()
datasets
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df = df.iloc[:10]
df
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
import pandas as pd

pd.Categorical(df['embark_town'])
# Out:
# ['Southampton', 'Cherbourg', 'Southampton', 'Southampton', 'Southampton', 'Queenstown', 'Southampton', 'Southampton', 'Southampton', 'Cherbourg']
# Categories (3, object): ['Cherbourg', 'Queenstown', 'Southampton']

# %%
df[df['age']>30]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 6    man        True    E  Southampton    no   True

# %%
df[df['fare'] == max(df['fare'])]['who']
# Out:
# 1    woman
# Name: who, dtype: object

# %%
df.iloc[2:4, 0:5]  # Row from 2:4 and col from 0,1,2
# Out:
#    survived  pclass     sex   age  sibsp
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1

# %%
df.loc[2:4, ['who', 'age']]
# Out:
#      who   age
# 2  woman  26.0
# 3  woman  35.0
# 4    man  35.0

# %%
df.groupby('embark_town').size()
# Out:
# embark_town
# Cherbourg      2
# Queenstown     1
# Southampton    7
# dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    7
# Cherbourg      2
# Queenstown     1
# Name: count, dtype: int64

# %%
new_slice =  df[['fare','embarked', 'class', 'who','adult_male']][5:9]
new_slice
# Out:
#       fare embarked  class    who  adult_male
# 5   8.4583        Q  Third    man        True
# 6  51.8625        S  First    man        True
# 7  21.0750        S  Third  child       False
# 8  11.1333        S  Third  woman       False

# %%
concat_data1 = pd.concat([new_slice, df],  axis=1)
concat_data1
# Out:
#       fare embarked  class    who  adult_male  survived  pclass     sex   age  \
# 5   8.4583        Q  Third    man        True         0       3    male   NaN
# 6  51.8625        S  First    man        True         0       1    male  54.0
# 7  21.0750        S  Third  child       False         0       3    male   2.0
# 8  11.1333        S  Third  woman       False         1       3  female  27.0
# 0      NaN      NaN    NaN    NaN         NaN         0       3    male  22.0
# 1      NaN      NaN    NaN    NaN         NaN         1       1  female  38.0
# 2      NaN      NaN    NaN    NaN         NaN         1       3  female  26.0
# 3      NaN      NaN    NaN    NaN         NaN         1       1  female  35.0
# 4      NaN      NaN    NaN    NaN         NaN         0       3    male  35.0
# 9      NaN      NaN    NaN    NaN         NaN         1       2  female  14.0
#
#    sibsp  parch     fare embarked   class    who  adult_male deck  \
# 5      0      0   8.4583        Q   Third    man        True  NaN
# 6      0      0  51.8625        S   First    man        True    E
# 7      3      1  21.0750        S   Third  child       False  NaN
# 8      0      2  11.1333        S   Third  woman       False  NaN
# 0      1      0   7.2500        S   Third    man        True  NaN
# 1      1      0  71.2833        C   First  woman       False    C
# 2      0      0   7.9250        S   Third  woman       False  NaN
# 3      1      0  53.1000        S   First  woman       False    C
# 4      0      0   8.0500        S   Third    man        True  NaN
# 9      1      0  30.0708        C  Second  child       False  NaN
#
#    embark_town alive  alone
# 5   Queenstown    no   True
# 6  Southampton    no   True
# 7  Southampton    no  False
# 8  Southampton   yes  False
# 0  Southampton    no  False
# 1    Cherbourg   yes  False
# 2  Southampton   yes   True
# 3  Southampton   yes  False
# 4  Southampton    no   True
# 9    Cherbourg   yes  False

# %%
concat_data1 = pd.concat([new_slice, df],  axis=0)
concat_data1
# Out:
#       fare embarked   class    who  adult_male  survived  pclass     sex  \
# 5   8.4583        Q   Third    man        True       NaN     NaN     NaN
# 6  51.8625        S   First    man        True       NaN     NaN     NaN
# 7  21.0750        S   Third  child       False       NaN     NaN     NaN
# 8  11.1333        S   Third  woman       False       NaN     NaN     NaN
# 0   7.2500        S   Third    man        True       0.0     3.0    male
# 1  71.2833        C   First  woman       False       1.0     1.0  female
# 2   7.9250        S   Third  woman       False       1.0     3.0  female
# 3  53.1000        S   First  woman       False       1.0     1.0  female
# 4   8.0500        S   Third    man        True       0.0     3.0    male
# 5   8.4583        Q   Third    man        True       0.0     3.0    male
# 6  51.8625        S   First    man        True       0.0     1.0    male
# 7  21.0750        S   Third  child       False       0.0     3.0    male
# 8  11.1333        S   Third  woman       False       1.0     3.0  female
# 9  30.0708        C  Second  child       False       1.0     2.0  female
#
#     age  sibsp  parch deck  embark_town alive  alone
# 5   NaN    NaN    NaN  NaN          NaN   NaN    NaN
# 6   NaN    NaN    NaN  NaN          NaN   NaN    NaN
# 7   NaN    NaN    NaN  NaN          NaN   NaN    NaN
# 8   NaN    NaN    NaN  NaN          NaN   NaN    NaN
# 0  22.0    1.0    0.0  NaN  Southampton    no  False
# 1  38.0    1.0    0.0    C    Cherbourg   yes  False
# 2  26.0    0.0    0.0  NaN  Southampton   yes   True
# 3  35.0    1.0    0.0    C  Southampton   yes  False
# 4  35.0    0.0    0.0  NaN  Southampton    no   True
# 5   NaN    0.0    0.0  NaN   Queenstown    no   True
# 6  54.0    0.0    0.0    E  Southampton    no   True
# 7   2.0    3.0    1.0  NaN  Southampton    no  False
# 8  27.0    0.0    2.0  NaN  Southampton   yes  False
# 9  14.0    1.0    0.0  NaN    Cherbourg   yes  False

# %%
new_slice
# Out:
#       fare embarked  class    who  adult_male
# 5   8.4583        Q  Third    man        True
# 6  51.8625        S  First    man        True
# 7  21.0750        S  Third  child       False
# 8  11.1333        S  Third  woman       False

# %%
new_slice['fare'].apply(lambda x: x*2)
# Out:
# 5     16.9166
# 6    103.7250
# 7     42.1500
# 8     22.2666
# Name: fare, dtype: float64

# %%
new_slice.reset_index(drop=True)
# Out:
#       fare embarked  class    who  adult_male
# 0   8.4583        Q  Third    man        True
# 1  51.8625        S  First    man        True
# 2  21.0750        S  Third  child       False
# 3  11.1333        S  Third  woman       False

# %%
for row in new_slice.iterrows():
  print(row)
# Out:
# (5, fare          8.4583
# embarked           Q
# class          Third
# who              man
# adult_male      True
# Name: 5, dtype: object)
# (6, fare          51.8625
# embarked            S
# class           First
# who               man
# adult_male       True
# Name: 6, dtype: object)
# (7, fare          21.075
# embarked           S
# class          Third
# who            child
# adult_male     False
# Name: 7, dtype: object)
# (8, fare          11.1333
# embarked            S
# class           Third
# who             woman
# adult_male      False
# Name: 8, dtype: object)

# %%
new_slice
# Out:
#       fare embarked  class    who  adult_male
# 5   8.4583        Q  Third    man        True
# 6  51.8625        S  First    man        True
# 7  21.0750        S  Third  child       False
# 8  11.1333        S  Third  woman       False

# %%
def subtract(x):
  return abs(x-10)

new_slice['fare'].apply(subtract) vs new_slice['fare'].apply(lambda x: x-10)
# Out:
# 5     1.5417
# 6    41.8625
# 7    11.0750
# 8     1.1333
# Name: fare, dtype: float64

# %%
new_slice['fare'].apply(lambda x: x-10)
# Out:
# 5    -1.5417
# 6    41.8625
# 7    11.0750
# 8     1.1333
# Name: fare, dtype: float64

# %%
new_slice['fare'].sort_values(ascending=False)
# Out:
# 6    51.8625
# 7    21.0750
# 8    11.1333
# 5     8.4583
# Name: fare, dtype: float64

# %%
new_slice['fare'].sort_index(ascending=True)
# Out:
# 5     8.4583
# 6    51.8625
# 7    21.0750
# 8    11.1333
# Name: fare, dtype: float64

# %%
new_slice['fare'].rolling(window=2).mean()
# Out:
# 5         NaN
# 6    30.16040
# 7    36.46875
# 8    16.10415
# Name: fare, dtype: float64

# %%
import pandas as pd

dates = pd.date_range(start='1998-03-02', end='2005-06-05', periods=10)
pd.DataFrame(dates)
# Out:
#                     0
# 0 1998-03-02 00:00:00
# 1 1998-12-21 16:00:00
# 2 1999-10-12 08:00:00
# 3 2000-08-02 00:00:00
# 4 2001-05-23 16:00:00
# 5 2002-03-14 08:00:00
# 6 2003-01-03 00:00:00
# 7 2003-10-24 16:00:00
# 8 2004-08-14 08:00:00
# 9 2005-06-05 00:00:00

# %%
pd.Timedelta(days=5)

start = pd.Timestamp('2025-10-31')
end = start + pd.Timedelta(days=10)

print(end)
# Out:
# 2025-11-10 00:00:00
