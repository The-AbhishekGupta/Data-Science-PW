# %% [markdown]
# Q3. Measure the three measures of central tendency for the given height data:
#
# [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
import numpy as np

values = np.array([178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5])

# %%
from scipy import stats
import pandas as pd

mean_data = np.mean(values)

median_data = np.median(values)

mod_data = stats.mode(values)

summary_df = pd.DataFrame({
    "Mean": [mean_data],
    "Median": [median_data],
    "Mode": [mod_data]
})

summary_df
# Out:
#         Mean  Median        Mode
# 0  177.01875   177.0  (177.0, 3)

# %% [markdown]
# Q4. Find the standard deviation for the given data:
# [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
import numpy as np
import pandas as pd

values = np.array([178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5])

std_value = np.std(values)

std = pd.DataFrame({'Standard Deviation': [std_value]})

std
# Out:
#    Standard Deviation
# 0            1.788581

# %% [markdown]
# ```
#
# Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
# (i) A ∩ B (ii) A ⋃ B
#
# A = (2,3,4,5,6,7) B = (0,2,6,8,10)
#
# A ∩ B : (A intersection B)
# This represents the A intersection B which means all the common elements between A and B.
# The output of the intersections of the above set will be (2,6)
# A ⋃ B : (A union B)
# This represents the A union B which means all the elements of A and B ie,distinct elements.
# The output of the union of the above set will be (0,2,3,4,5,6,7,8,10)
#
# ```

# %%
A = set((2,3,4,5,6,7))
B = set((0,2,6,8,10))

a_intersection_b = A.intersection(B)
a_union_b = A.union(B)

display(a_intersection_b, a_union_b)
# Out:
# {2, 6}
# {0, 2, 3, 4, 5, 6, 7, 8, 10}
